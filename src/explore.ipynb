# %% [markdown]
# # Explore here
#
# It's recommended to use this notebook for exploration purposes.
#
# For example:
#
# 1. You could import the CSV generated by python into your notebook and explore it.
# 2. You could connect to your database using `pandas.read_sql` from this notebook and explore it.

# %%
# Example reading the SQL database from here
import pandas as pd

import numpy as np

import matplotlib.pyplot as plt

import seaborn as sns

"""from utils import db_connect
import pandas as pd
engine = db_connect()

dataframe = pd.read_sql("Select * from books;", engine)
print(dataframe.describe())"""
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /workspace/machine-learning-python-template/src/explore.ipynb Cell 2' in <cell line: 2>()
#       <a href='vscode-notebook-cell://marfurt1-machinelearnin-855pmfjxwbv.ws-us47.gitpod.io/workspace/machine-learning-python-template/src/explore.ipynb#ch0000001vscode-remote?line=0'>1</a> # Example reading the SQL database from here
# ----> <a href='vscode-notebook-cell://marfurt1-machinelearnin-855pmfjxwbv.ws-us47.gitpod.io/workspace/machine-learning-python-template/src/explore.ipynb#ch0000001vscode-remote?line=1'>2</a> import pandas as pd
#       <a href='vscode-notebook-cell://marfurt1-machinelearnin-855pmfjxwbv.ws-us47.gitpod.io/workspace/machine-learning-python-template/src/explore.ipynb#ch0000001vscode-remote?line=3'>4</a> import numpy as np
#       <a href='vscode-notebook-cell://marfurt1-machinelearnin-855pmfjxwbv.ws-us47.gitpod.io/workspace/machine-learning-python-template/src/explore.ipynb#ch0000001vscode-remote?line=5'>6</a> import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'pandas'

# %%
# Example importing the CSV here
df_airbnb = pd.read_csv('../data/raw/AB_NYC_2019.csv')
# dataframe = pd.read_csv('../path/to/file.csv')
# dataframe.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /workspace/machine-learning-python-template/src/explore.ipynb Cell 3' in <cell line: 2>()
#       <a href='vscode-notebook-cell://marfurt1-machinelearnin-855pmfjxwbv.ws-us47.gitpod.io/workspace/machine-learning-python-template/src/explore.ipynb#ch0000002vscode-remote?line=0'>1</a> # Example importing the CSV here
# ----> <a href='vscode-notebook-cell://marfurt1-machinelearnin-855pmfjxwbv.ws-us47.gitpod.io/workspace/machine-learning-python-template/src/explore.ipynb#ch0000002vscode-remote?line=1'>2</a> df_airbnb = pd.read_csv('../data/raw/AB_NYC_2019.csv')
#
# NameError: name 'pd' is not defined

# %%
numeric_desc, categorical_desc = my_df_describe(df_airbnb,name = 'airbnb',show = True, save=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /workspace/machine-learning-python-template/src/explore.ipynb Cell 4' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://marfurt1-machinelearnin-855pmfjxwbv.ws-us47.gitpod.io/workspace/machine-learning-python-template/src/explore.ipynb#ch0000004vscode-remote?line=0'>1</a> numeric_desc, categorical_desc = my_df_describe(df_airbnb,name = 'airbnb',show = True, save=False)
#
# NameError: name 'my_df_describe' is not defined
